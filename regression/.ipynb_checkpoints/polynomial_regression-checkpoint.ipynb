# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
# %matplotlib inline

# %%
def create_poly_features(x, degree=2):
    X_poly = np.zeros((x.shape[0],degree))
    
    for i in range(0,degree):
            X_poly[:,i] = x**(i+1)
            
    return X_poly

def generate_data(N,degree=2):
    X = np.random.rand(N)*2
    Y =  1 + 1*X + 20*X**2 + 10*np.random.randn(N)

    X_poly = create_poly_features(X,degree)
    return X, X_poly, Y

# %%
degree = 8
X_train, X_poly_train, Y_train = generate_data(6, degree=degree)
X_test, X_poly_test, Y_test = generate_data(20,degree=degree)

# %%
plt.figure()
plt.scatter(X_train,Y_train,color='r',label='training data')
plt.xlabel('temperature (celsius)')
plt.ylabel('power usage (W)')
plt.show()

# %%
mu = np.mean(X_poly_train,axis=0,keepdims=True)
std = np.std(X_poly_test,axis=0,keepdims=True)

X_poly_train = (X_poly_train - mu)/std

X_poly_test = (X_poly_test-mu)/std

# %%
plt.figure()
plt.scatter(X_poly_train[:,0],Y_train,color='r',label='training data')
plt.xlabel('temperature (celsius)')
plt.ylabel('power usage (W)')
plt.show()

plt.figure()
plt.scatter(X_poly_train[:,1],Y_train,color='r',label='training data')
plt.xlabel('temperature (celsius)')
plt.ylabel('power usage squared (W)')
plt.show()

# %%
def MSE(Y,x,theta,b,model,lam=0.0):
    Yhat = model(x,theta,b)
    return np.mean((Y-Yhat)**2) + lam*np.sum(theta**2)

def poly(x,theta,b):
    return np.sum(theta*x,axis=1)+b

def gradient(x,y,theta,b,model,lam=0.0):
    yhat = model(x,theta,b)
    dtheta = -2*np.mean((y-yhat)[:,np.newaxis]*x,axis=0) + 2*lam*theta
    db = -2*np.mean(y-yhat)
    
    return dtheta,db

def gradient_descent(Theta,b,X_train,Y_train,X_test,Y_test,loss,gradient,model,
                     N_iterations=1000,print_every=100,learning_rate=1e-3,lam=0.0):
    train_loss = []
    test_loss = []
    iters = []
    thetas = []
    for i in range(N_iterations):
            dtheta,db = gradient(X_train,Y_train,Theta,b,model,lam)
            
            for j in range(len(Theta)):
                Theta[j] -= learning_rate*dtheta[j]
            b -= learning_rate*db

            if (i+1)%print_every == 0:
                e = loss(Y_train,X_train,Theta,b,model,lam)
                train_loss.append(e)

                e_test = loss(Y_test,X_test,Theta,b,model,lam)
                test_loss.append(e_test)

                iters.append(i)
                thetas.append(Theta.copy())
                print "Iteration {}: Theta={}, b={}, MSE_train = {}, MSE_test = {}".format(i,Theta,b,e,e_test)
                
    thetas = np.asarray(thetas)
    
    return Theta,b,thetas,train_loss,test_loss,iters

# %%
learning_rate = 1e-4
N_iterations = 1000000
Theta = np.asarray([1.0]*degree)
b = 1.0
print_every = 100000

# %%
Theta,b,thetas,train_loss,test_loss,iters = gradient_descent(Theta,b,X_poly_train,Y_train,X_poly_test,Y_test,
        MSE,gradient,poly, N_iterations=N_iterations,print_every=print_every,learning_rate=learning_rate)
# Out:
# Iteration 99999: Theta=[ 8.45595189  7.73695058  5.67865539  3.66599193  2.15307906  1.16886962
#   0.60428947  0.33062665], b=34.2621266988, MSE_train = 35.4820891341, MSE_test = 225.434671595
# Iteration 199999: Theta=[ 11.15142656   9.32118842   5.79688812   2.65417418   0.48138299
#   -0.77193157  -1.34088534  -1.46547587], b=34.2621267672, MSE_train = 33.0391267874, MSE_test = 153.475785374
# Iteration 299999: Theta=[ 13.45591787  10.68593943   5.9093585    1.79347344  -0.9539193
#   -2.44730295  -3.02749783  -3.02904939], b=34.2621267672, MSE_train = 31.2274490327, MSE_test = 168.544525473
# Iteration 399999: Theta=[ 15.42478117  11.8628087    6.01784939   1.06369173  -2.18504999
#   -3.89364828  -4.49111406  -4.39213239], b=34.2621267672, MSE_train = 29.8835947348, MSE_test = 239.084316033
# Iteration 499999: Theta=[ 17.104732    12.87793761   6.12290448   0.44660296  -3.24042214
#   -5.14283208  -5.76275377  -5.58260924], b=34.2621267672, MSE_train = 28.8864304218, MSE_test = 342.89181818
# Iteration 599999: Theta=[ 18.53598523  13.75382969   6.22499156  -0.07348306  -4.14449535
#   -6.22228511  -6.86912044  -6.62448434], b=34.2621267672, MSE_train = 28.1461882492, MSE_test = 464.587523641
# Iteration 699999: Theta=[ 19.75315991  14.50985718   6.32451334  -0.51007321  -4.9183257
#   -7.15562118  -7.83320183  -7.53842194], b=34.2621267672, MSE_train = 27.5963443583, MSE_test = 593.701702715
# Iteration 799999: Theta=[ 20.78605788  15.1626967    6.42181652  -0.87479495  -5.58003935
#   -7.96316828  -8.67478698  -8.3422109 ], b=34.2621267672, MSE_train = 27.1876002064, MSE_test = 723.276100186
# Iteration 899999: Theta=[ 21.6603341   15.72670433   6.51719954  -1.17765774  -6.14524022
#   -8.6624258   -9.41091133  -9.0511648 ], b=34.2621267672, MSE_train = 26.8834223394, MSE_test = 848.845081937
# Iteration 999999: Theta=[ 22.39807365  16.21423855   6.61091934  -1.42727827  -6.627361
#   -9.26845813 -10.0562399   -9.67846636], b=34.2621267672, MSE_train = 26.65673707, MSE_test = 967.695601249

# %%
plt.plot(iters,train_loss,linewidth=2,color='r',label='Training loss')
plt.plot(iters,test_loss, linewidth=2, color='g', label='Test loss')
plt.xlabel('Gradient-Descent Iterations')
plt.legend()
plt.show()

# %%
thetas = np.asarray(thetas)

plt.plot(iters,thetas[:,0],linewidth=2,color='r',label=r'$\theta_1$')
plt.plot(iters,thetas[:,1],linewidth=2,color='g',label=r'$\theta_2$')
plt.xlabel('Gradient-Descent Iterations')
plt.legend()
plt.show()

# %%
X = np.arange(0.0,2.1,0.1)
X = create_poly_features(X,degree)
X = (X-mu)/std
Yhat = poly(X,Theta,b)
X = X*std+mu

# %%
plt.figure()
plt.scatter(X_train,Y_train, color='r', label='Training Data')
plt.scatter(X_test,Y_test, color='b', label='Test Data')
plt.plot(X[:,0],Yhat, color='g', linewidth=2, label=r'Optimized fit')
plt.xlabel('Square feet')
plt.ylabel('House price ($)')
plt.legend(loc='upper left')
plt.show()

# %%
Theta = np.asarray([1.0]*degree)
b = 1.0
lam = 0.1

# %%
Theta,b,thetas,train_loss,test_loss,iters = gradient_descent(Theta,b,X_poly_train,Y_train,X_poly_test,Y_test,
        MSE,gradient,poly, N_iterations=N_iterations,print_every=print_every,learning_rate=learning_rate,lam=lam)
# Out:
# Iteration 99999: Theta=[ 5.75096111  5.76035367  4.67267666  3.4100793   2.3365861   1.53381619
#   0.97627283  0.60880761], b=34.2621266988, MSE_train = 50.2550896984, MSE_test = 235.001317116
# Iteration 199999: Theta=[ 5.92052442  5.88575082  4.70457812  3.35623824  2.22183544  1.38248883
#   0.80687656  0.43363755], b=34.2621267672, MSE_train = 50.2355818791, MSE_test = 227.877163541
# Iteration 299999: Theta=[ 5.93950329  5.90048817  4.70882973  3.35047939  2.20870154  1.3647023
#   0.78657722  0.4122941 ], b=34.2621267672, MSE_train = 50.2353127989, MSE_test = 227.081525901
# Iteration 399999: Theta=[ 5.94161124  5.90222444  4.70939925  3.3498795   2.20720443  1.36260995
#   0.78413675  0.40968156], b=34.2621267672, MSE_train = 50.235309068, MSE_test = 226.988504121
# Iteration 499999: Theta=[ 5.94184288  5.90242934  4.70947563  3.34981922  2.20703448  1.36236345
#   0.78384221  0.40936015], b=34.2621267672, MSE_train = 50.2353090159, MSE_test = 226.977552775
# Iteration 599999: Theta=[ 5.94186798  5.90245356  4.70948588  3.34981349  2.20701528  1.36233437
#   0.78380651  0.4093204 ], b=34.2621267672, MSE_train = 50.2353090151, MSE_test = 226.976260517
# Iteration 699999: Theta=[ 5.94187065  5.90245643  4.70948726  3.349813    2.20701313  1.36233093
#   0.78380217  0.40931546], b=34.2621267672, MSE_train = 50.2353090151, MSE_test = 226.976107735
# Iteration 799999: Theta=[ 5.94187093  5.90245677  4.70948744  3.34981297  2.20701289  1.36233052
#   0.78380164  0.40931484], b=34.2621267672, MSE_train = 50.2353090151, MSE_test = 226.976089633
# Iteration 899999: Theta=[ 5.94187096  5.90245681  4.70948747  3.34981297  2.20701286  1.36233048
#   0.78380157  0.40931476], b=34.2621267672, MSE_train = 50.2353090151, MSE_test = 226.976087483
# Iteration 999999: Theta=[ 5.94187096  5.90245682  4.70948747  3.34981297  2.20701286  1.36233047
#   0.78380156  0.40931475], b=34.2621267672, MSE_train = 50.2353090151, MSE_test = 226.976087227

# %%
X = (X-mu)/std
Yhat = poly(X,Theta,b)
X = X*std+mu

# %%
plt.figure()
plt.scatter(X_train,Y_train, color='r', label='Training Data')
plt.scatter(X_test,Y_test, color='b', label='Test Data')
plt.plot(X[:,0],Yhat, color='g', linewidth=2, label=r'Optimized fit')
plt.xlabel('Square feet')
plt.ylabel('House price ($)')
plt.legend(loc='upper left')
plt.show()

# %%
X_train, X_poly_train, Y_train = generate_data(20, degree=degree)

X_poly_test = X_poly_test*std+mu

mu = np.mean(X_poly_train,axis=0,keepdims=True)
std = np.std(X_poly_test,axis=0,keepdims=True)

X_poly_train = (X_poly_train - mu)/std
X_poly_test = (X_poly_test-mu)/std

learning_rate = 1e-4
N_iterations = 20000
Theta = np.asarray([5.0]*degree)
b = 20.0
print_every = 2000
lam=0.0

# %%
Theta,b,thetas,train_loss,test_loss,iters = gradient_descent(Theta,b,X_poly_train,Y_train,X_poly_test,Y_test,
        MSE,gradient,poly, N_iterations=N_iterations,print_every=print_every,learning_rate=learning_rate,lam=lam)
# Out:
# Iteration 1999: Theta=[ 4.72618957  4.184048    3.54652482  2.76236516  1.80334597  0.72125245
#  -0.23753193 -0.3782605 ], b=21.9399409905, MSE_train = 72.1213257627, MSE_test = 304.108355641
# Iteration 3999: Theta=[ 5.00817569  4.35010832  3.60183934  2.71659505  1.66201936  0.51055414
#  -0.41355894 -0.20601485], b=23.2402703035, MSE_train = 62.2106961509, MSE_test = 285.738297504
# Iteration 5999: Theta=[ 5.30052432  4.54542853  3.70919537  2.74829316  1.62148772  0.40837391
#  -0.52145089 -0.12639793], b=24.111872239, MSE_train = 57.5303707028, MSE_test = 266.882891719
# Iteration 7999: Theta=[ 5.57965067  4.72998094  3.81047708  2.77989648  1.58763548  0.31852543
#  -0.61802356 -0.05682322], b=24.6961011157, MSE_train = 55.0679217658, MSE_test = 253.001508232
# Iteration 9999: Theta=[ 5.84521007  4.90249685  3.90327406  2.80770447  1.55555674  0.23565405
#  -0.70669161  0.00727582], b=25.0877057767, MSE_train = 53.6431441836, MSE_test = 242.50557665
# Iteration 11999: Theta=[ 6.09799189  5.0636407   3.9879896   2.83177789  1.52491482  0.15907915
#  -0.78810564  0.06645292], b=25.3501957299, MSE_train = 52.7211343404, MSE_test = 234.279939127
# Iteration 13999: Theta=[ 6.3387922   5.21412937  4.0651374   2.85235396  1.49561219  0.08838512
#  -0.8627445   0.12103615], b=25.5261409685, MSE_train = 52.0570808608, MSE_test = 227.65257761
# Iteration 15999: Theta=[ 6.56835935  5.35463899  4.13520536  2.86966399  1.46756866  0.02319413
#  -0.93104987  0.17132296], b=25.6440758708, MSE_train = 51.5370600616, MSE_test = 222.201857525
# Iteration 17999: Theta=[ 6.7873943   5.48580289  4.19865069  2.88392498  1.44070968 -0.03684698
#  -0.99343495  0.21759133], b=25.7231268375, MSE_train = 51.1064395862, MSE_test = 217.649598047
# Iteration 19999: Theta=[ 6.99655342  5.60821411  4.25590146  2.89534013  1.41496544 -0.09206887
#  -1.05028654  0.26010151], b=25.7761141652, MSE_train = 50.737650959, MSE_test = 213.80381698

# %%
X = (X-mu)/std
Yhat = poly(X,Theta,b)
X = X*std+mu

# %%
plt.figure()
plt.scatter(X_train,Y_train, color='r', label='Training Data')
plt.scatter(X_test,Y_test, color='b', label='Test Data')
plt.plot(X[:,0],Yhat, color='g', linewidth=2, label=r'Optimized fit')
plt.xlabel('Square feet')
plt.ylabel('House price ($)')
plt.legend(loc='upper left')
plt.show()
