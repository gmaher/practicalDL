# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
np.random.seed(0)
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['font.size'] = 13
fig_path = '/home/gabriel/practicaldl/latex/figures/supervised/'

# %%
N_train = 400
N_test = 400
noise = 50
male_avg = np.asarray([70,170])
male_std = np.asarray([7,10])

female_avg = np.asarray([60,150])
female_std = np.asarray([5,8])

X_train = np.zeros((N_train,2))
Y_train = np.zeros((N_train))

X_test = np.zeros((N_test,2))
Y_test = np.zeros((N_test))

X_train[:N_train/2,:] = np.random.randn(N_train/2,2)*male_std+male_avg
X_train[N_train/2:,:] = np.random.randn(N_train/2,2)*female_std+female_avg
Y_train[N_train/2:] = 1

X_test[:N_test/2,:] = np.random.randn(N_test/2,2)*male_std+male_avg
X_test[N_test/2:,:] = np.random.randn(N_test/2,2)*female_std+female_avg
Y_test[N_test/2:] = 1

# %%
plt.figure()
plt.scatter(X_train[:N_train/2,0],X_train[:N_train/2,1], color='r', label='males')
plt.scatter(X_train[N_train/2:,0],X_train[N_train/2:,1], color='b', label='females')
plt.xlabel('weight (kg)')
plt.ylabel('height (cm)')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_train.pdf',dpi=600)
plt.show()

# %%
for j in range(10):
    i = np.random.randint(X_train.shape[0])
    print "weight = {}, height = {}, male/female={}".format(X_train[i,0], X_train[i,1], Y_train[i])
# Out:
# weight = 58.6917727714, height = 148.54204173, male/female=1.0
# weight = 74.7060632991, height = 174.074618362, male/female=0.0
# weight = 63.5999186507, height = 141.176750296, male/female=1.0
# weight = 58.2627467375, height = 145.349852185, male/female=1.0
# weight = 86.682013424, height = 179.44479487, male/female=0.0
# weight = 61.421398354, height = 163.941350245, male/female=1.0
# weight = 55.7051380578, height = 142.808462748, male/female=1.0
# weight = 63.5999186507, height = 141.176750296, male/female=1.0
# weight = 65.8258017308, height = 169.474327037, male/female=0.0
# weight = 57.4124047874, height = 142.169361125, male/female=1.0

# %%
plt.figure()
plt.scatter(X_test[:N_test/2,0],X_test[:N_test/2,1], color='r', label='males')
plt.scatter(X_test[N_test/2:,0],X_test[N_test/2:,1], color='b', label='females')
plt.xlabel('weight (kg)')
plt.ylabel('height (cm)')
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig(fig_path+'log_test.pdf',dpi=600)
plt.show()

# %%
mu = np.mean(X_train,axis=0)
std = np.std(X_train,axis=0)

X_train = (X_train-mu)/std
X_test = (X_test-mu)/std

# %%
plt.figure()
plt.scatter(X_train[:N_train/2,0],X_train[:N_train/2,1], color='r', label='males')
plt.scatter(X_train[N_train/2:,0],X_train[N_train/2:,1], color='b', label='females')
plt.xlabel('weight normalized')
plt.ylabel('height normalized')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_norm.pdf',dpi=600)
plt.show()

# %%
def sigmoid(x):
    return 1.0/(1+np.exp(-x))

def classify(x,theta,b):
    a = np.sum(x*theta,axis=1)+b
    return sigmoid(a)

def binaryCrossEntropy(y,x,theta,b,model,lam=0.0):
    eps = 1e-5
    yhat = model(x,theta,b)
    l = np.mean(-(1-y)*np.log((1-yhat+eps)) - y*np.log(yhat+eps)) +\
        lam*np.sum(theta**2)
    return l

def gradient(y,x,theta,b,model,lam=0.0):
    eps=1e-5
    yhat = model(x,theta,b)
    temp = (yhat-y)/(yhat*(1-yhat)+eps)*yhat*(1-yhat)
    temp = temp[:,np.newaxis]
    
    dtheta= np.mean(temp*x,axis=0) +2*lam*theta
    db= np.mean(temp)
    return dtheta,db

def gradient_descent(Theta,b,X_train,Y_train,X_test,Y_test,loss,gradient,model,
                     N_iterations=1000,print_every=100,learning_rate=1e-3,lam=0.0):
    train_loss = []
    test_loss = []
    iters = []
    thetas = []
    biases = []
    for i in range(N_iterations):
            dtheta,db = gradient(Y_train,X_train,Theta,b,model,lam)
            
            for j in range(len(Theta)):
                Theta[j] -= learning_rate*dtheta[j]
            b -= learning_rate*db

            if (i+1)%print_every == 0:
                e = loss(Y_train,X_train,Theta,b,model,lam)
                train_loss.append(e)

                e_test = loss(Y_test,X_test,Theta,b,model,lam)
                test_loss.append(e_test)

                iters.append(i)
                thetas.append(Theta.copy())
                biases.append(b)
                print "Iteration {}: Theta={}, b={}, loss_train = {}, loss_test = {}".format(i,Theta,b,e,e_test)
                
    thetas = np.asarray(thetas)
    
    return Theta,b,thetas,biases,train_loss,test_loss,iters

# %%
learning_rate = 5e-3
N_iterations = 10000
Theta = np.asarray([1.0,1.0])
b = 1.0
print_every = 200
train_loss = []
test_loss = []
iters = []
thetas = []
biases = []
Theta,b,thetas,biases,train_loss,test_loss,iters = gradient_descent(Theta,b,X_train,Y_train,X_test,Y_test,
        binaryCrossEntropy,gradient,classify, N_iterations=N_iterations,print_every=print_every,learning_rate=learning_rate)
# Out:
# Iteration 199: Theta=[ 0.49803142  0.43222798], b=0.836872431048, loss_train = 1.1662743835, loss_test = 1.18982253863
# Iteration 399: Theta=[ 0.09985045 -0.0180828 ], b=0.666078989324, loss_train = 0.773598591941, loss_test = 0.779691526141
# Iteration 599: Theta=[-0.18703851 -0.34921449], b=0.524365722309, loss_train = 0.559779716772, loss_test = 0.555557734575
# Iteration 799: Theta=[-0.38982159 -0.59209603], b=0.419036982964, loss_train = 0.447796534387, loss_test = 0.439067658598
# Iteration 999: Theta=[-0.54041291 -0.77930427], b=0.340466182652, loss_train = 0.383603793199, loss_test = 0.373048820819
# Iteration 1199: Theta=[-0.65863691 -0.9310031 ], b=0.279852853599, loss_train = 0.342817643704, loss_test = 0.331530942477
# Iteration 1399: Theta=[-0.75552786 -1.05864284], b=0.231548887898, loss_train = 0.314746925806, loss_test = 0.303174827749
# Iteration 1599: Theta=[-0.8374845 -1.1690169], b=0.192014569154, loss_train = 0.294254509702, loss_test = 0.282579078403
# Iteration 1799: Theta=[-0.90845984 -1.26641207], b=0.158956685811, loss_train = 0.278621209633, loss_test = 0.266912664712
# Iteration 1999: Theta=[-0.97104065 -1.35368738], b=0.13082880974, loss_train = 0.266286193983, loss_test = 0.254566027564
# Iteration 2199: Theta=[-1.02700303 -1.43283962], b=0.106549155956, loss_train = 0.256293003473, loss_test = 0.244561435524
# Iteration 2399: Theta=[-1.07761563 -1.50531724], b=0.0853366947614, loss_train = 0.248023724998, loss_test = 0.236272126333
# Iteration 2599: Theta=[-1.12381473 -1.57220438], b=0.0666121980187, loss_train = 0.24106152761, loss_test = 0.229278172081
# Iteration 2799: Theta=[-1.16631044 -1.63433406], b=0.0499361753551, loss_train = 0.235114965567, loss_test = 0.223287694884
# Iteration 2999: Theta=[-1.20565386 -1.69236058], b=0.0349685776082, loss_train = 0.229974032014, loss_test = 0.218091447454
# Iteration 3199: Theta=[-1.24228114 -1.74680774], b=0.0214418177695, loss_train = 0.225483477274, loss_test = 0.213535416385
# Iteration 3399: Theta=[-1.27654338 -1.79810167], b=0.00914221305795, loss_train = 0.221525976982, loss_test = 0.209503643189
# Iteration 3599: Theta=[-1.30872734 -1.846594  ], b=-0.00210308822023, loss_train = 0.218011157178, loss_test = 0.205907085067
# Iteration 3799: Theta=[-1.3390703  -1.89257851], b=-0.0124355120345, loss_train = 0.214868229489, loss_test = 0.202676177783
# Iteration 3999: Theta=[-1.36777082 -1.93630333], b=-0.0219719529029, loss_train = 0.212040922528, loss_test = 0.199755741099
# Iteration 4199: Theta=[-1.39499674 -1.9779801 ], b=-0.0308099124401, loss_train = 0.209483914856, loss_test = 0.197101408712
# Iteration 4399: Theta=[-1.42089123 -2.0177909 ], b=-0.0390313869393, loss_train = 0.207160274311, loss_test = 0.19467707534
# Iteration 4599: Theta=[-1.44557739 -2.05589362], b=-0.0467058483544, loss_train = 0.20503958677, loss_test = 0.192453037756
# Iteration 4799: Theta=[-1.46916186 -2.09242613], b=-0.0538925580787, loss_train = 0.203096566671, loss_test = 0.190404618852
# Iteration 4999: Theta=[-1.49173763 -2.1275096 ], b=-0.0606423828054, loss_train = 0.201310010178, loss_test = 0.188511134034
# Iteration 5199: Theta=[-1.51338627 -2.16125116], b=-0.0669992340502, loss_train = 0.199661996064, loss_test = 0.186755104281
# Iteration 5399: Theta=[-1.53417975 -2.193746  ], b=-0.073001219907, loss_train = 0.198137268296, loss_test = 0.185121649597
# Iteration 5599: Theta=[-1.55418187 -2.22507916], b=-0.0786815744045, loss_train = 0.196722753736, loss_test = 0.183598016206
# Iteration 5799: Theta=[-1.57344947 -2.25532692], b=-0.0840694132851, loss_train = 0.195407181547, loss_test = 0.182173204177
# Iteration 5999: Theta=[-1.59203341 -2.28455803], b=-0.089190353082, loss_train = 0.194180780052, loss_test = 0.180837671328
# Iteration 6199: Theta=[-1.60997937 -2.31283464], b=-0.0940670216262, loss_train = 0.19303503317, loss_test = 0.179583095696
# Iteration 6399: Theta=[-1.62732855 -2.34021318], b=-0.0987194816532, loss_train = 0.191962483162, loss_test = 0.178402183414
# Iteration 6599: Theta=[-1.64411821 -2.36674504], b=-0.10316558435, loss_train = 0.190956569677, loss_test = 0.177288512141
# Iteration 6799: Theta=[-1.6603822  -2.39247718], b=-0.107421266029, loss_train = 0.1900114975, loss_test = 0.176236402536
# Iteration 6999: Theta=[-1.67615133 -2.41745261], b=-0.111500798358, loss_train = 0.18912212719, loss_test = 0.175240812065
# Iteration 7199: Theta=[-1.69145373 -2.44171087], b=-0.115417000411, loss_train = 0.188283884071, loss_test = 0.174297246707
# Iteration 7399: Theta=[-1.70631516 -2.46528836], b=-0.119181419186, loss_train = 0.187492682086, loss_test = 0.173401687106
# Iteration 7599: Theta=[-1.72075927 -2.48821871], b=-0.122804483922, loss_train = 0.186744859727, loss_test = 0.172550526483
# Iteration 7799: Theta=[-1.73480783 -2.51053304], b=-0.126295638558, loss_train = 0.186037125858, loss_test = 0.171740518143
# Iteration 7999: Theta=[-1.74848091 -2.53226022], b=-0.129663455842, loss_train = 0.185366513692, loss_test = 0.170968730893
# Iteration 8199: Theta=[-1.76179705 -2.55342707], b=-0.132915736006, loss_train = 0.184730341503, loss_test = 0.170232510999
# Iteration 8399: Theta=[-1.77477345 -2.57405857], b=-0.136059592368, loss_train = 0.18412617896, loss_test = 0.169529449584
# Iteration 8599: Theta=[-1.78742603 -2.59417803], b=-0.139101525846, loss_train = 0.183551818149, loss_test = 0.168857354563
# Iteration 8799: Theta=[-1.79976963 -2.61380723], b=-0.142047490012, loss_train = 0.18300524854, loss_test = 0.168214226405
# Iteration 8999: Theta=[-1.81181805 -2.63296656], b=-0.144902948056, loss_train = 0.18248463529, loss_test = 0.167598237108
# Iteration 9199: Theta=[-1.82358416 -2.65167513], b=-0.147672922813, loss_train = 0.181988300354, loss_test = 0.167007711906
# Iteration 9399: Theta=[-1.83508   -2.6699509], b=-0.150362040802, loss_train = 0.181514706007, loss_test = 0.166441113293
# Iteration 9599: Theta=[-1.84631683 -2.68781074], b=-0.152974571109, loss_train = 0.181062440407, loss_test = 0.16589702703
# Iteration 9799: Theta=[-1.8573052  -2.70527055], b=-0.155514459788, loss_train = 0.180630204919, loss_test = 0.165374149851
# Iteration 9999: Theta=[-1.868055  -2.7223453], b=-0.15798536038, loss_train = 0.180216802951, loss_test = 0.164871278622

# %%
plt.plot(iters,train_loss,linewidth=2,color='r',label='Training loss')
plt.plot(iters,test_loss, linewidth=2, color='g', label='Test loss')
plt.xlabel('Gradient-Descent Iterations')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_loss.pdf',dpi=600)
plt.show()

# %%
thetas = np.asarray(thetas)
biases = np.asarray(biases)
print thetas.shape
plt.plot(iters,thetas[:,0],linewidth=2,color='r',label=r'$w_1$')
plt.plot(iters,thetas[:,1],linewidth=2,color='g',label=r'$w_2$')
plt.plot(iters,biases[:],linewidth=2,color='b',label=r'$b$')
plt.xlabel('Gradient-Descent Iterations')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_params.pdf',dpi=600)
plt.show()
# Out:
# (50, 2)

# %%
train_line = (-b-Theta[0]*X_train[:,0])/Theta[1]

# %%
plt.figure()
plt.scatter(X_train[:N_train/2,0],X_train[:N_train/2,1], color='r', label='males')
plt.scatter(X_train[N_train/2:,0],X_train[N_train/2:,1], color='b', label='females')
plt.plot(X_train[:,0],train_line,color='g',linewidth=2,label='decision boundary')
plt.xlabel('weight normalized')
plt.ylabel('height normalized')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_train_boundary.pdf',dpi=600)
plt.show()

# %%
test_line = (-b-Theta[0]*X_test[:,0])/Theta[1]

# %%
plt.figure()
plt.scatter(X_test[:N_test/2,0],X_test[:N_test/2,1], color='r', label='males')
plt.scatter(X_test[N_test/2:,0],X_test[N_test/2:,1], color='b', label='females')
plt.plot(X_test[:,0],test_line,color='g',linewidth=2,label='decision boundary')
plt.xlabel('weight normalized')
plt.ylabel('height normalized')
plt.legend()
plt.tight_layout()
plt.savefig(fig_path+'log_test_boundary.pdf',dpi=600)
plt.show()

# %%
ypred = sigmoid(np.sum(Theta*X_test,axis=1)+b)
ythresh = ypred.copy()
ythresh[ythresh>0.5] = 1
ythresh[ythresh<=0.5] = 0
accuracy = np.mean((ythresh.astype(int)==Y_test.astype(int)))
print "Test accuracy = {}%".format(accuracy*100)
# Out:
# Test accuracy = 94.25%

# %%
num_positives = np.sum(Y_test)
num_negatives = np.sum(1-Y_test)
TP = np.sum(Y_test*yhat)/num_positives
TN = np.sum((1-Y_test)*(1-ythresh))/num_negatives
FP = np.sum((1-Y_test)*ythresh)/num_positives
FN = np.sum((1-yhat)*Y_test)/num_negatives
print "True positive rate ={}".format(TP)
print "True negative rate ={}".format(TN)
print "False positive rate ={}".format(FP)
print "False negative rate ={}".format(FN)

# %%
def recall(y,yhat):
    TP = np.sum(y*yhat)
    FN = np.sum((1-yhat)*y)

    return float(TP)/(FN+TP)

def precision(y,yhat):
    FP = np.sum(yhat*(1-y))
    TP = np.sum(yhat*y)

    return float(TP)/(FP+TP)

# %%
precisions = []
recalls = []
for i in np.arange(0,1.0,0.001):
    yhat = ypred.copy()
    yhat[yhat>i] = 1.0
    yhat[yhat<=i] = 0.0
    p = precision(Y_test,yhat)
    r = recall(Y_test,yhat)
    
    precisions.append(p)
    recalls.append(r)

# %%
plt.figure()
plt.plot(recalls,precisions,linewidth=2)
plt.xlabel('recall')
plt.ylabel('precision')
plt.tight_layout()
plt.savefig(fig_path+'log_pr.pdf',dpi=600)
plt.show()
